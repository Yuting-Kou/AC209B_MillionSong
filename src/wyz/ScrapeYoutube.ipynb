# %%
import pprint
import os
import googleapiclient.discovery
import pandas as pd
import re
import html
import numpy as np
import time
import requests
from bs4 import BeautifulSoup

# %%
data = pd.read_csv('../../data/music.csv')

# %%
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

api_service_name = "youtube"
api_version = "v3"
#DEVELOPER_KEY = "AIzaSyAfpYYZXksE0NxDF1Zsgmxq9DgVzhRAKCo"
#DEVELOPER_KEY = "AIzaSyCRkutyAFmYOr9eYxReKZy_BXXeFsjBuXQ"
#DEVELOPER_KEY = "AIzaSyAZ8X4sVAVHSGaxFs2inv5i3XM-noHrb2I"
#DEVELOPER_KEY = "AIzaSyCpAauBldYXlcIRTij5UoA_UJobKERsRZw"
#DEVELOPER_KEY = "AIzaSyBOZw0_a5W82OreAUOTKvl8QUy7c7WL_M0"
#DEVELOPER_KEY = "AIzaSyAxY6pAf-mq259XwyTH35660NcCAiQ7KE8"
#DEVELOPER_KEY = "AIzaSyBAtj09vwRybKPIkzYL-LSRfcopA7jR_J0"
#DEVELOPER_KEY = "AIzaSyCS0kzosldQOSHWblcOsoY5KKxH4B9yJaM"
#DEVELOPER_KEY = "AIzaSyALeOdLq_SWsGGEguA_czjf3Cgi4XIzCLI"
#DEVELOPER_KEY = "AIzaSyB0JOV5aujqhO9ZAgm7ZIj4e5Jg0yEnWQQ"
#DEVELOPER_KEY = "AIzaSyDXm-CztvYsIPyB0y6j8qNBI6-zLEDDq6M"
#DEVELOPER_KEY = "AIzaSyBYENjLoOQ1978cuBF9DUR2TGz54XdBT7c"

DEVELOPER_KEY = "AIzaSyD7g31cyw55MmdNnhjHnjg7hYDzwyb0YNg"
DEVELOPER_KEY = "AIzaSyA5E3JVk2dvtvtlPIqgrfyqsHfqBO_oYaU"
DEVELOPER_KEY = "AIzaSyBGmx9cztRveJnDGnVazixvjt_EG3y8H6E"
DEVELOPER_KEY = "AIzaSyCwsXuhtBd5GQHw7mq_GQtm-qU1A3Ov_-E"
DEVELOPER_KEY = "AIzaSyA7S6Nv-0J-7gVyfjcS6_4u9Sd8nYMIPuo"
DEVELOPER_KEY = "AIzaSyCbn-WhZD-WSgZIbAymrVS_X2G1DXiMnnY"
DEVELOPER_KEY = "AIzaSyAxmTv0Y5eduDqRbLG2VrpkzW78Kg2JM-M"
DEVELOPER_KEY = "AIzaSyD0GdivG7wBW-p0Fa0AxAGZaOhhB_AncxI"
DEVELOPER_KEY = "AIzaSyBuWWf5IsHDECsYlNjLyf_UPBWV1rMPeeM"
DEVELOPER_KEY = "AIzaSyBZpPFD6KbXuKDk8AIJtlxXoOGnrU_xSXY"
DEVELOPER_KEY = "AIzaSyByqaEz749zFZ7UPgxc-boUe4PfwLEHiek"
DEVELOPER_KEY = "AIzaSyAQhguBNAl-cu-xu_LaYCAw7wQfhaDLPmo"
DEVELOPER_KEY = "AIzaSyANVcM9hqFpWGQ6sXLli_EjId0iYQrqA60"
DEVELOPER_KEY = "AIzaSyBELMoryYCIxMNLiB7q6ykRFujJpbyNT3M"
DEVELOPER_KEY = "AIzaSyBGwMb2Q0f1A8RsY8BwS_ehz-Em-p7lYR4"
DEVELOPER_KEY = "AIzaSyA1nCJONaJAxJaUAnIj6vPsVA-A_We-VrY"
DEVELOPER_KEY = "AIzaSyD1RSUHyYR7b8Me6Y0RUvHXasFnuYxutdk"
#DEVELOPER_KEY = "AIzaSyC9CwxlhXmN9u7bVf7n_9eZ_pVmRodhcGQ"
#DEVELOPER_KEY = "AIzaSyAgjA95Mo4BvrcUchotM7OmWCYUME5ckag"
#DEVELOPER_KEY = "AIzaSyBD5PSq9s8SVm8pdiS9sYGUztg0aku4oIE"
#DEVELOPER_KEY = "AIzaSyCaILPDeRfPISvjARo63EZyhGdAMJSi-GM"
#DEVELOPER_KEY = "AIzaSyBfSEmF2BrMgOuFj-TX3UXV25vySsRhTiI"
#DEVELOPER_KEY = "AIzaSyCAPqz9QMK_BCNawhq_FwMnTOzlfDxU6Ts"
#DEVELOPER_KEY = "AIzaSyAMWNw78IVecMwy6R8qeoe_wtbPNEGL9d4"
#DEVELOPER_KEY = "AIzaSyC9FitmJClFR1zIvdpGHsgQ4vjaqAe6kZM"
#DEVELOPER_KEY = "AIzaSyBg5PpyaO4_EHigxPdUdPsvEWCLCrkCL5A"
#DEVELOPER_KEY = "AIzaSyBCPr7IaKItcuL6o5j5Omsg5teiaECUPug"
#DEVELOPER_KEY = "AIzaSyDCWgKHb7j6fJjtPigt0s0o1VXl31LsA8c"
#DEVELOPER_KEY = "AIzaSyBgBs8ZfOthzpaZ4esU9wAY2HeieZh9ado"
#DEVELOPER_KEY = "AIzaSyDG6JxV2kThFSQjPgnY5PhemHignkfHrqU"
#DEVELOPER_KEY = "AIzaSyCAH9ceBnego1oS8rurCvWPjTXCgkmqOPs"
#DEVELOPER_KEY = "AIzaSyBCMQB2oQRVh8iUaYzC05TKIk66qn5M_ck"
#DEVELOPER_KEY = "AIzaSyDhH5TmmMnqVqW06MUorapTrPUlyvQde1s"
#DEVELOPER_KEY = "AIzaSyDGq9WtQUE5rn87kX_ncjVTcyuPzkv7CgI"
#DEVELOPER_KEY = "AIzaSyAFo42RraCSG2HKq7AuetdeYZXe8J9Aefo"
#DEVELOPER_KEY = "AIzaSyBzyQoByhz4AwR2wj36QLoCuL9pUUuZxbg"
#DEVELOPER_KEY = "AIzaSyAX8m23d2qk6TQ3yJX20aDABeg5Swayfg8"
#DEVELOPER_KEY = "AIzaSyBEmTf0njtfhGUbpXXnI73LFQMH6nHIitI"
#DEVELOPER_KEY = "AIzaSyBWGrjACiS98mvb8sfGKuoC243HJmN3vNg"
#DEVELOPER_KEY = "AIzaSyDd_ZB5OfUFI7iuWah92VAWh6izP4MnXyk"
#DEVELOPER_KEY = "AIzaSyDtjMzuGeuqxVvq97L_Q1-Cv8JUJ8MDByg"
#DEVELOPER_KEY = "AIzaSyBNEqJ365XVwjaaFa6qgaHFcXAhZjy7i-8"
#DEVELOPER_KEY = "AIzaSyANfG2zaEwdK3ob0jhY9xhDc0EgAal3Eug"
#DEVELOPER_KEY = "AIzaSyD_Ddy77LDym41c926SB1yA1YoA1H__r0s"
#DEVELOPER_KEY = "AIzaSyAqDRfcMaMlQxfIazl1D8NrR89Y44FmEBM"
#DEVELOPER_KEY = "AIzaSyBR6GOA9IKVSb51-jhoCxiLet51WoP0lgk"
#DEVELOPER_KEY = "AIzaSyBhenw27oynm5xYfmccxXbtZa-DUSfXnsU"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
# method 1: use youtube data api
j = i
for i in range(j, 10000):
    if pd.isnull(data.loc[i,'title']):
        continue
    if hotness[i] > 0:
        continue
    query = data.loc[i,'title'] + ' ' + data.loc[i,'artist.name']
    query = re.sub("[\(\[].*?[\)\]]", "", query)
    query = re.sub(r'[^A-Za-z0-9\']+', ' ', query)
    print(i, query)
    '''
    if data.loc[i,'duration'] < 240:
        dur = 'short'
    elif data.loc[i,'duration'] > 1200:
        dur = 'long'
    else:
        dur = 'medium'
    '''
    request = youtube.search().list(
        part = 'snippet',
        maxResults=5,
        type = 'video',
        q = query
    )
    response = request.execute()['items']
    videoID = []
    list_of_words = query.split()
    for item in response:
        sentence = item['snippet']['description']+' ' + item['snippet']['title']
        sentence = html.unescape(sentence)
        if all(re.compile(r'\b'+w+r'\b', re.IGNORECASE).search(sentence) for w in list_of_words):
            videoID.append(item['id']['videoId'])
    if len(videoID) == 0:
        continue
    request = youtube.videos().list(
        part = 'statistics',
        id = ', '.join(videoID)
    )
    response = request.execute()['items']
    for item in response:
        hotness[i] += int(item['statistics']['viewCount'])
    print(hotness[i])
# Out:
# 9850 YksinA isin Solistiyhtye Suomi
# 9852 So Still Danny Wright
# 259.0
# 9855 Now Is A Needy Time David Evans
# 458.0
# 9865 I'm Against It Horse Feathers The Marx Brothers
# 9869 Les Reves DA'enfants Monty
# 9870 BAkA si tA ncdallamok Muzsikas
# 9882  Breakin' Up The Ronettes
# 9883 Kapitel 4 Oliver Kalkofe
# 9891 You are the summer Gloria
# 9903 Thats life Sane Band
# 9904 Hard Hitters Dilated Peoples Featuring Black Thought
# 9907 Two Elegiac Melodies Op 34 2 The Last Spring Sir Neville Marriner
# 9911 The Little Stack Of Barley Cronin's Hornpipe SAamus Ennis
# 9912 Gutes MA dchen Hassan Annouri
# 9913 Spend the Night featuring Rock Money and Paul Law Tech N9ne
# 9915 Patience Guns N' Roses
# 9922 CocoricA3 HAlio Ziskind
# 9929 Gabriel's Oboe Carlos NuA ez
# 9934 Come On Home Michael English
# 9936 Brasil pandeiro Mart'nA lia
# 9939 Rapaz De Bem Sivuca
# 9943 The Drama X Ecutioners featuring Big Pun
# 9944 Track BALLERINA GIRL Antonio Koudele
# 9946 Break Em Ultra X
# ...

# %%
hotness = np.loadtxt('../../data/hotness.csv')

# %%
sum(hotness == 0)
# Out:
# 1915

# %%
np.savetxt('../../data/hotness1.csv', hotness)

# %%
import pprint

request = youtube.search().list(
    part="snippet",
    maxResults=5,
    q="I Didn't Mean To Casual",
    type = 'video',
    videoDuration = 'short'
)
response1 = request.execute()

pprint.pprint(response1)
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/3GyyN9AlSa6Cy3E6x-5e2ZblTVg"',
#  'items': [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/UpXaUR9sGTtXFojI8692czHkH9A"',
#             'id': {'kind': 'youtube#video', 'videoId': 'gHGYEljjY2M'},
#             'kind': 'youtube#searchResult',
#             'snippet': {'channelId': 'UCJkAPp7yrWEW4wknm4sz5MA',
#                         'channelTitle': '11EViDENCE',
#                         'description': 'Album: Fear Itself.',
#                         'liveBroadcastContent': 'none',
#                         'publishedAt': '2011-03-22T19:39:07.000Z',
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/gHGYEljjY2M/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
# ...

# %%
request = youtube.videos().list(
    part="statistics",
    id="oScZuIp6ce8, 6GHQy-E9Jws"
)
response2 = request.execute()
pprint.pprint(response2)
# Out:
# {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/AUb_wpd7GwM1eDuWb-a9l1cBYtY"',
#  'items': [{'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/OHQhcCafTQT5zIu6QRr58Q-F-Bw"',
#             'id': 'oScZuIp6ce8',
#             'kind': 'youtube#video',
#             'statistics': {'commentCount': '132',
#                            'dislikeCount': '180',
#                            'favoriteCount': '0',
#                            'likeCount': '2855',
#                            'viewCount': '995054'}},
#            {'etag': '"XpPGQXPnxQJhLgs6enD_n8JR4Qk/L8PpvNg5E7QVH1b0mRxSAG3Qpw0"',
#             'id': '6GHQy-E9Jws',
#             'kind': 'youtube#video',
#             'statistics': {'commentCount': '378',
#                            'dislikeCount': '986',
#                            'favoriteCount': '0',
#                            'likeCount': '12122',
#                            'viewCount': '10624201'}}],
#  'kind': 'youtube#videoListResponse',
# ...

# %%
res = pd.DataFrame(hotness, columns = ['hotness'])
res.describe()
# Out:
#             hotness
# count  1.000000e+04
# mean   1.854394e+06
# std    1.948723e+07
# min    0.000000e+00
# 25%    2.700000e+01
# 50%    3.022000e+03
# 75%    5.838225e+04
# max    6.457510e+08

# %%
# method 2: scrape myself
j = i
for i in range(j, data.shape[0]):
    if pd.isnull(data.loc[i,'title']):
        continue
    if hotness2[i] > 0:
        continue
    query = data.loc[i,'title'] + ' ' + data.loc[i,'artist.name']
    query = re.sub("[\(\[].*?[\)\]]", "", query)
    query = re.sub(r'[^\w^\d^\']+', ' ', query)
    print(i, query)
    URL = 'https://www.youtube.com/results?search_query='+query+'&sp=EgIQAQ%253D%253D'
    response = requests.get(URL)
    star_soup = BeautifulSoup(response.text, 'html.parser')
    
    title = star_soup.find_all('span', {"aria-label":True})
    desc = star_soup.find_all('div', {'class':"yt-lockup-description yt-ui-ellipsis yt-ui-ellipsis-2"})
    view = star_soup.find_all('ul', {"class":"yt-lockup-meta-info"})
    list_of_words = query.split()
    for j in range(min(5, len(desc))):
        sentence = title[j+1].text + ' ' + desc[j].text
        sentence = html.unescape(sentence)
        if all(re.compile(r'\b'+w+r'\b', re.IGNORECASE).search(sentence) for w in list_of_words):
            cnt_view = re.findall(r'(\d*,?\d+)\sviews?', view[j].text)
            if (len(cnt_view) == 0):
                continue
            hotness2[i] += int(cnt_view[0].replace(',',''))
    time.sleep(2)
    print(hotness2[i])
# Out:
# 224 Beyond the Light Aberdeen
# 202.0
# 226 Pulecenella 'e mA2 Gloriana
# 0.0
# 227 Iskorosten' Butterfly Temple
# 0.0
# 229 It Goes On 20 20
# 0.0
# 230 Pecado De Amor JosA Augusto
# 0.0
# 234 A B Is A B N W A
# 0.0
# 240 4 Sea Interludes Op 33a Storm Sir Neville Marriner
# 0.0
# 245 Smile Xcultures
# 0.0
# 250 Oh Look Misery Blind Blake The Royal Victoria Hotel Calypsos
# 0.0
# 253 Palmer enquAate Alexandre Desplat
# 0.0
# 255 Moon River Original Jerry Butler
# 0.0
# 265 The First Noel Carl Doy with NZSO
# 0.0
# 268 Drop the Bass The Nightraver The Magican
# 0.0
# 273 The Boss Lady May
# 44196.0
# 275 Jeffrey's Dark Side Angelo Badalamenti
# 0.0
# 277 Milagre Dos Peixes Musica Incidental Cais Music Incidental San Vicente Cesar Camargo Mariano Helio Delmiro
# 0.0
# 278 Pinned To The Ground Buzzhorn
# 17993.0
# 287 Estate Billy Higgins_ Bob Berg_ Cedar Walton_ Tony Dumas
# 0.0
# 295 Quiero Ir Ao Mar Carlos NuA ez
# 0.0
# 298 Bloco Da Solidao Maysa
# 0.0
# ...

# %%
# method 3: use someone else's scraper
for i in range(6764, data.shape[0]):
    query = data.loc[i,'title'] + ' ' + data.loc[i,'artist.name']
    query = re.sub("[\(\[].*?[\)\]]", "", query)
    query = re.sub(r'[^\w^\d^\']+', ' ', query)
    print(i, query)
    URL = 'http://youtube-scrape.herokuapp.com/api/search?q='+query+'&page=1'
    response = requests.get(URL).json()['results']
    videoID = []
    list_of_words = query.split()
    for j in range(min(5, len(response))):
        item = response[j]
        sentence = item['video']['title']+ ' ' + item['video']['snippet']
        sentence = html.unescape(sentence)
        if all(re.compile(r'\b'+w+r'\b', re.IGNORECASE).search(sentence) for w in list_of_words):
            view = item['video']['views'].replace(",", "")
            if view.isdigit():
                hotness1[i] += int(view)
# Out:
# 6764 Celebration Madonna
# 6765 Granada RamA3n Vargas
# 6766 Xoanina Susana Seivane
# 6767 Fefita Orquesta Aragon
# 6768 Fade Away Cama
# 6769 She Can't Burn Me Now The Del McCoury Band
# 6770 O Brother Monty Are I
# 6771 The Special Two Missy Higgins
# 6772 Asha Asha Puthli
# 6773 Soki Olingi Ngai Wendo Kolosoy
# 6774 Colin Tries Standing Zbigniew Preisner
# 6775 Likua Cabas
# 6776 The Dropsonde Caspian
# 6777 Tulsa Girl Dwight Twilley
# 6778 Il Tempo Non Torna PiA1 Kati
# 6779 Gone Kanye West Consequence Cam'Ron
# 6780 My Fault Faces
# 6781 Nomads Alive Marco Beltrami
# 6782 The Only Road Dropkick Murphys
# 6783 Jimmie's Travellin' Blues Jimmie Davis
# 6784 Memory In The Snow Michael Gettel
# 6785 Dave D Blues Mayday
# 6786 My Baby Likes To Shuffle Sonny Terry
# 6787 Mr De's Theme Mr De'
# 6788 Chere Duloone Al Rapone
# 6789 Un jour aux courses Who's That Man The Marx Brothers
# 6790 You Know What They Do To Guys Like Us In Prison My Chemical Romance
# ...

# %%
data[['song.hotttnesss', 'title', 'year', 'artist.name']]
# Out:
#       song.hotttnesss                                              title  \
# 0            0.602120                                   I Didn't Mean To
# 1                 NaN                                          Soul Deep
# 2                 NaN                                    Amor De Cabaret
# 3                 NaN                                    Something Girls
# 4            0.604501                                     Face the Ashes
# 5                 NaN        The Moon And I (Ordinary Day Album Version)
# 6                 NaN                              Keepin It Real (Skit)
# 7                 NaN                                       Drop of Rain
# 8            0.265861                                         Pink World
# 9                 NaN                  Insatiable (Instrumental Version)
# 10           0.000000                                    Young Boy Blues
# 11           0.265861                           The Urgency (LP Version)
# ...
